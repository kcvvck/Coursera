# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('<name of website>') # returns a file handler # like an opening
for line in fhand: # line is a byte array
    print(line.decode().strip()) # need to decode

# %%
# scrap - assignment 

# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")

# Retrieve all of the anchor tags
totalSum=0
tags = soup('span')
for tag in tags:
    totalSum += int(tag.contents[0]) # add all numbers in span tag
print("sum is", totalSum)
# Out:
# Enter - http://py4e-data.dr-chuck.net/comments_1093505.html
# sum is 2755

# %%
# get all web links on a webpage

# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
urlList = []
position = 17
i = 0

while i < 7:
    html = urlopen(url, context=ctx).read()
    soup = BeautifulSoup(html, "html.parser")

    # Retrieve all of the anchor tags
    tags = soup('a')
    url = tags[position].get('href', None)
    print(tags[position].contents[0])
    i +=1
# Out:
# Enter - http://py4e-data.dr-chuck.net/known_by_Youssef.html
# Jeemie
# Emaly
# Fraser
# Kirk
# Fenn
# Francis
# Keyra

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")

# Retrieve all of the anchor tags
# urlList = []
tags = soup('a')
for tag in tags:
    # Look at the parts of a tag
#     print('TAG:', tag)
    print('URL:', tag.get('href', None))
#     urlList.append(tag.get('href', None))
    print('Contents:', tag.contents[0])
#     print('Attrs:', tag.attrs)
# print(urlList)
# Out:
# Enter - http://py4e-data.dr-chuck.net/known_by_Fikret.html
# URL: http://py4e-data.dr-chuck.net/known_by_Aniqa.html
# Contents: Aniqa
# URL: http://py4e-data.dr-chuck.net/known_by_Ogheneruno.html
# Contents: Ogheneruno
# URL: http://py4e-data.dr-chuck.net/known_by_Montgomery.html
# Contents: Montgomery
# URL: http://py4e-data.dr-chuck.net/known_by_Owain.html
# Contents: Owain
# URL: http://py4e-data.dr-chuck.net/known_by_Haniyah.html
# Contents: Haniyah
# URL: http://py4e-data.dr-chuck.net/known_by_Anona.html
# Contents: Anona
# URL: http://py4e-data.dr-chuck.net/known_by_Edyn.html
# Contents: Edyn
# URL: http://py4e-data.dr-chuck.net/known_by_Dallace.html
# Contents: Dallace
# URL: http://py4e-data.dr-chuck.net/known_by_Zoe.html
# Contents: Zoe
# URL: http://py4e-data.dr-chuck.net/known_by_Kiarash.html
# Contents: Kiarash
# URL: http://py4e-data.dr-chuck.net/known_by_Tracy.html
# Contents: Tracy
# URL: http://py4e-data.dr-chuck.net/known_by_Carmyle.html
# Contents: Carmyle
# ...

# %%
# Beautiful soup for html
# web crawler
